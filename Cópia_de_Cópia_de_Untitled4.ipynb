# %% [markdown]
# <a href="https://colab.research.google.com/github/FabioRamosAntonio/CSharpe/blob/main/C%C3%B3pia_de_C%C3%B3pia_de_Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importando pacote para trazer a URl Pra a análise
import urllib.request

# %%
#Criando uma váriavel para armazenar o Objeto de conexao à URL como Parametro
url = 'https://goyaperfumaria.com.br/'
resposta = urllib.request.urlopen(url)

# %%
print(resposta)

# %%
html_Pagina = resposta.read()

# %%
print(html_Pagina)
# Out:
# b' <!doctype html><html lang="pt"><head > <script>\n    var BASE_URL = \'https://goyaperfumaria.com.br/\';\n    var require = {\n        "baseUrl": "https://goyaperfumaria.com.br/static/frontend/Codazon/fastest_bigmarket/pt_BR"\n    };</script> <meta charset="utf-8"/>\n<meta name="description" content="Seus cosm\xc3\xa9ticos em um s\xc3\xb3 lugar!  | GOYA PERFUMARIAS | entrega r\xc3\xa1pida  para os cuidados da sua Beleza. "/>\n<meta name="keywords" content="Perfumaria goya, goya perfumaria, perfumaria online, cosm\xc3\xa9tico, cosm\xc3\xa9ticos, progressiva comprar, shampoo, condicionador, let me be, unha gel, creme massagem, perfume, m\xc3\xa1scara cabelo,"/>\n<meta name="robots" content="INDEX,FOLLOW"/>\n<meta name="title" content="Perfumaria GOYA | Os melhores pre\xc3\xa7os em cosm\xc3\xa9ticos"/>\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no"/>\n<meta name="format-detection" content="telephone=no"/>\n<title>Perfumaria GO
# ...

# %%
import pandas as pd
dflist = pd.read_html('https://goyaperfumaria.com.br/')
dflist[0].head()
# Out:
# Exception ignored in: <function URLopener.__del__ at 0x7f267a48ef70>
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/urllib/request.py", line 1741, in __del__
#     self.close()
#   File "/usr/lib/python3.8/urllib/request.py", line 1744, in close
#     self.cleanup()
#   File "/usr/lib/python3.8/urllib/request.py", line 1757, in cleanup
#     if self.tempcache:
# AttributeError: 'URLopener' object has no attribute 'tempcache'
